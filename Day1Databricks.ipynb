# %%
events = load_ecommerce_data("oct")

print(f"✅ Ready to go! Loaded {events.count():,} events")
events.show(5, truncate=False)
# Out:
# ✅ Ready to go! Loaded 42,448,764 events
# +-------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |event_time         |event_type|product_id|category_id        |category_code                      |brand   |price  |user_id  |user_session                        |
# +-------------------+----------+----------+-------------------+-----------------------------------+--------+-------+---------+------------------------------------+
# |2019-10-01 00:00:00|view      |44600062  |2103807459595387724|NULL                               |shiseido|35.79  |541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# |2019-10-01 00:00:00|view      |3900821   |2053013552326770905|appliances.environment.water_heater|aqua    |33.2   |554748717|9333dfbd-b87a-4708-9857-6336556b0fcc|
# ...

# %%
def load_ecommerce_data(month):
    file_map = {
        "oct": "/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",
        "nov": "/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv"
    }

    path = file_map.get(month.lower())
    if path is None:
        raise ValueError("Use 'oct' or 'nov'")

    return (
        spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv(path)
    )

# %%
display(dbutils.fs.ls("dbfs:/Volumes/workspace/ecommerce/ecommerce_data"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv</td><td>2019-Nov.csv</td><td>9006762395</td><td>1767992500000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv</td><td>2019-Oct.csv</td><td>5668612855</td><td>1767992644000</td></tr><tr><td>dbfs:/Volumes/workspace/ecommerce/ecommerce_data/ecommerce-behavior-data-from-multi-category-store.zip</td><td>ecommerce-behavior-data-from-multi-category-store.zip</td><td>4606720907</td><td>1767992413000</td></tr></tbody></table></div>

# %%
 events = spark.read.csv("/FileStore/tables/2019_Oct.csv",
                          header=True, inferSchema=True)

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
df.show(5, truncate=False)
# Out:
# ...
# SAMPLE DATA (First 5 rows):
# ...
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+------+---------+------------------------------------+
# |_c0                    |_c1       |_c2       |_c3                |_c4                                |_c5     |_c6   |_c7      |_c8                                 |
# +-----------------------+----------+----------+-------------------+-----------------------------------+--------+------+---------+------------------------------------+
# |event_time             |event_type|product_id|category_id        |category_code                      |brand   |price |user_id  |user_session                        |
# |2019-10-01 00:00:00 UTC|view      |44600062  |2103807459595387724|NULL                               |shiseido|35.79 |541312140|72d76fde-8bb3-4e00-8c23-a032dfed738c|
# ...

# %%
print(f"October 2019 - Total Events: {df.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df.printSchema()
# Out:
# October 2019 - Total Events: 42,448,765
#
# ...
# SCHEMA:
# ...
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#  |-- _c8: string (nullable = true)

# %%
df = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# %%
df_n = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv")

# %%
# %restart_python

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
unzip -o ecommerce-behavior-data-from-multi-category-store.zip
ls -lh
# Out:
# Archive:  ecommerce-behavior-data-from-multi-category-store.zip
#   inflating: 2019-Nov.csv
#   inflating: 2019-Oct.csv
# total 18G
# -rwxrwxrwx 1 spark-7fd15aa0-ebea-4012-95ac-b5 nogroup 8.4G Jan  9 21:01 2019-Nov.csv
# -rwxrwxrwx 1 spark-7fd15aa0-ebea-4012-95ac-b5 nogroup 5.3G Jan  9 21:04 2019-Oct.csv
# -rwxrwxrwx 1 spark-7fd15aa0-ebea-4012-95ac-b5 nogroup 4.3G Jan  9 21:00 ecommerce-behavior-data-from-multi-category-store.zip

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store
# License(s): copyright-authors
# ...
# 100%|██████████| 4.29G/4.29G [00:54<00:00, 85.3MB/s]

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")
# Out:
# DataFrame[]

# %%
import os

os.environ["KAGGLE_USERNAME"] = "naveenrs2121999"
os.environ["KAGGLE_KEY"] = "923ca8a3482299f459a68163071a4bef"

print("Kaggle credentials configured!")
# Out:
# Kaggle credentials configured!

# %%
# !pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
